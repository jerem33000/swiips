# %%
import csv
import re
import numpy as np

percent = 0
input_word = ""

# Fonction de prétraitement des compétences
def preprocess_skill(skill):
    skill = skill.lower()  # Conversion en minuscules
    skill = re.sub(r'[^\w\s]', '', skill)  # Suppression de la ponctuation
    return skill

# Fonction pour charger les données à partir d'un fichier CSV
def load_data(file_path):
    skills = []
    with open(file_path, 'r', encoding='utf-8') as file:
        reader = csv.reader(file)
        for row in reader:
            skills.extend(row)
    return skills

# Fonction pour créer un vocabulaire à partir des compétences
def create_vocab(data):
    all_skills = ' '.join(data).split()
    vocab = set(all_skills)
    return vocab

# Fonction pour encoder les compétences en vecteurs one-hot
def encode_skills(data, vocab):
    encoded_skills = []
    for skill in data:
        encoded_skill = np.zeros(len(vocab))
        for idx, word in enumerate(vocab):
            if word in skill:
                encoded_skill[idx] = 1
        encoded_skills.append(encoded_skill)
    return np.array(encoded_skills)

# Fonction pour calculer la similarité de cosinus entre deux compétences
def cosine_similarity(skill1_vec, skill2_vec):
    dot_product = np.dot(skill1_vec, skill2_vec)
    norm_skill1 = np.linalg.norm(skill1_vec)
    norm_skill2 = np.linalg.norm(skill2_vec)
    if norm_skill1 == 0 or norm_skill2 == 0:
        return 0  # Si l'un des vecteurs est nul, la similarité est zéro
    similarity = dot_product / (norm_skill1 * norm_skill2)
    return similarity

# Exemple d'utilisation
file_path = 'skills1.csv'  # Chemin vers votre fichier CSV
search_word_path = 'CV_word.txt'  # Chemin vers votre fichier texte

# Chargement des données à partir du fichier CSV
data = load_data(file_path)

# Prétraitement des compétences
data = [preprocess_skill(skill) for skill in data]

# Charger les données à partir du fichier texte
with open(search_word_path, 'r', encoding='latin-1') as file:
    search_words = [preprocess_skill(word) for word in file.readlines()]

# Création du vocabulaire
vocab = create_vocab(data)

# Encodage des compétences en vecteurs one-hot
data_encoded = encode_skills(data, vocab)
search_words_encoded = encode_skills(search_words, vocab)

# Calcul de la similarité de cosinus entre chaque mot de recherche et toutes les compétences du dataset
similarities = []
for search_word_encoded in search_words_encoded:
    word_similarities = []
    for skill_encoded in data_encoded:
        similarity = cosine_similarity(search_word_encoded, skill_encoded)
        word_similarities.append(similarity)
    similarities.append(word_similarities)

# Affichage des mots de recherche et de leur similarité avec chaque compétence
for search_word, word_similarities in zip(search_words, similarities):
    # print(f"Similarities between '{search_word}' and all skills:")
    for skill, similarity in zip(data, word_similarities):
        if percent < similarity :
            percent = similarity
            input_word = skill

    print("Le mot avec le plus de similarité du mot '"+ str(search_word) + "' est : '" + str(input_word) + "' avec : " + str(round(percent * 100)) + "%")
    percent = 0
# Out:
# Le mot avec le plus de similarité du mot 'contactezmoi
# ' est : 'contact client' avec : 77%
# Le mot avec le plus de similarité du mot '
# ' est : 'contact client' avec : 0%
# Le mot avec le plus de similarité du mot '9 1 chemin de la plane 31700
# ' est : 'succession planning' avec : 71%
# Le mot avec le plus de similarité du mot 'cornebarrieu
# ' est : 'archivage' avec : 80%
# Le mot avec le plus de similarité du mot '
# ' est : 'archivage' avec : 0%
# Le mot avec le plus de similarité du mot ' jeremybourguetoutlookfr
# ' est : 'outlook' avec : 63%
# Le mot avec le plus de similarité du mot '
# ' est : 'outlook' avec : 0%
# Le mot avec le plus de similarité du mot 'fin wwwlinkedincominjérémy
# ' est : 'linkedin' avec : 77%
# Le mot avec le plus de similarité du mot 'bourguet
# ' est : 'préouverture' avec : 67%
# Le mot avec le plus de similarité du mot '
# ' est : 'préouverture' avec : 0%
# Le mot avec le plus de similarité du mot ' 0679 42 29 16
# ' est : 'web 20' avec : 41%
# Le mot avec le plus de similarité du mot '
# ' est : 'web 20' avec : 0%
# Le mot avec le plus de similarité du mot 'competences
# ' est : 'competitive intelligence' avec : 71%
# Le mot avec le plus de similarité du mot '
# ' est : 'competitive intelligence' avec : 0%
# Le mot avec le plus de similarité du mot 'hard skills
# ' est : 'dolibar' avec : 68%
# Le mot avec le plus de similarité du mot 'java
# ' est : 'core java' avec : 63%
# Le mot avec le plus de similarité du mot 'html  css
# ' est : 'css' avec : 82%
# Le mot avec le plus de similarité du mot 'php
# ' est : 'php' avec : 100%
# Le mot avec le plus de similarité du mot '
# ' est : 'php' avec : 0%
# Le mot avec le plus de similarité du mot 'javascript
# ' est : 'javascript' avec : 100%
# Le mot avec le plus de similarité du mot 'soft skills
# ' est : 'analytical skills' avec : 52%
# Le mot avec le plus de similarité du mot '
# ' est : 'analytical skills' avec : 0%
# Le mot avec le plus de similarité du mot 'autonome
# ' est : 'autonomie' avec : 87%
# Le mot avec le plus de similarité du mot '
# ' est : 'autonomie' avec : 0%
# Le mot avec le plus de similarité du mot 'sérieux
# ' est : 'généreux' avec : 82%
# Le mot avec le plus de similarité du mot 'travailleur
# ' est : 'joaillerie' avec : 75%
# Le mot avec le plus de similarité du mot '
# ' est : 'joaillerie' avec : 0%
# Le mot avec le plus de similarité du mot 'curieux
# ' est : 'curieux ' avec : 100%
# Le mot avec le plus de similarité du mot '
# ' est : 'curieux ' avec : 0%
# Le mot avec le plus de similarité du mot 'centres dinteret
# ' est : 'recherche et développement r et d' avec : 77%
# Le mot avec le plus de similarité du mot 'astronomie
# ' est : 'persuasion' avec : 87%
# Le mot avec le plus de similarité du mot 'jeux vidéo  création et divertissement
# ' est : 'se transcender' avec : 64%
# Le mot avec le plus de similarité du mot '
# ' est : 'se transcender' avec : 0%
# Le mot avec le plus de similarité du mot 'les technologies  tout type de domaine
# ' est : 'debouchage' avec : 55%
# Le mot avec le plus de similarité du mot '
# ' est : 'debouchage' avec : 0%
# Le mot avec le plus de similarité du mot 'jeremy bourguet
# ' est : 'préouverture' avec : 67%
# Le mot avec le plus de similarité du mot '27 ans
# ' est : 'solvabilité 2' avec : 63%
# Le mot avec le plus de similarité du mot '
# ' est : 'solvabilité 2' avec : 0%
# Le mot avec le plus de similarité du mot 'expert en informatique et
# ' est : 'informatique' avec : 84%
# Le mot avec le plus de similarité du mot '
# ' est : 'informatique' avec : 0%
# Le mot avec le plus de similarité du mot 'systeme dinformation
# ' est : 'système dinformation' avec : 95%
# Le mot avec le plus de similarité du mot 'actuellement en entreprise
# ' est : 'entreprise durable' avec : 80%
# Le mot avec le plus de similarité du mot '
# ' est : 'entreprise durable' avec : 0%
# Le mot avec le plus de similarité du mot 'profil personnel
# ' est : 'développement personnel' avec : 61%
# Le mot avec le plus de similarité du mot '
# ' est : 'développement personnel' avec : 0%
# Le mot avec le plus de similarité du mot 'actuellement en troisiéme année dataia je souhaite
# ' est : 'data center' avec : 72%
# Le mot avec le plus de similarité du mot 'continuer jusquau mastere autonome je serai madapter a
# ' est : 'tedx master coach' avec : 65%
# Le mot avec le plus de similarité du mot 'toutes les situations je fais énormément dautoformation
# ' est : 'formation et développement' avec : 58%
# Le mot avec le plus de similarité du mot 'pour pouvoir me conformer a toutes les technologies le plus
# ' est : 'sustainable tourism' avec : 51%
# Le mot avec le plus de similarité du mot 'rapidement possible
# ' est : 'liderazgo' avec : 72%
# Le mot avec le plus de similarité du mot '
# ' est : 'liderazgo' avec : 0%
# Le mot avec le plus de similarité du mot 'parcours professionnel
# ' est : 'coach professionnel' avec : 68%
# Le mot avec le plus de similarité du mot '
# ' est : 'coach professionnel' avec : 0%
# Le mot avec le plus de similarité du mot 'e développeur web  autoentrepreneur  toulouse
# ' est : 'customer service representatives' avec : 61%
# Le mot avec le plus de similarité du mot 'depuis juin 2022
# ' est : 'dessin' avec : 60%
# Le mot avec le plus de similarité du mot '
# ' est : 'dessin' avec : 0%
# Le mot avec le plus de similarité du mot 'dans le domaine de linformatique
# ' est : 'informatique' avec : 73%
# Le mot avec le plus de similarité du mot '
# ' est : 'informatique' avec : 0%
# Le mot avec le plus de similarité du mot 'développeur junior  cgi  toulouse  doctobre 2022 a
# ' est : 'communication de crise' avec : 60%
# Le mot avec le plus de similarité du mot 'octobre 2025
# ' est : 'crypto' avec : 61%
# Le mot avec le plus de similarité du mot '
# ' est : 'crypto' avec : 0%
# Le mot avec le plus de similarité du mot 'e net dotnet c
# ' est : 'déchet' avec : 75%
# Le mot avec le plus de similarité du mot '
# ' est : 'déchet' avec : 0%
# Le mot avec le plus de similarité du mot 'e vuejs vuetify axios nuxtjs
# ' est : 'vuejs' avec : 45%
# Le mot avec le plus de similarité du mot '
# ' est : 'vuejs' avec : 0%
# Le mot avec le plus de similarité du mot ' sol
# ' est : 'vuejs' avec : 0%
# Le mot avec le plus de similarité du mot '
# ' est : 'vuejs' avec : 0%
# Le mot avec le plus de similarité du mot 'projet
# ' est : 'équipes projet' avec : 77%
# Le mot avec le plus de similarité du mot '
# ' est : 'équipes projet' avec : 0%
# Le mot avec le plus de similarité du mot 'e projet ydays dun site web listant les informations
# ' est : 'système dinformation' avec : 57%
# Le mot avec le plus de similarité du mot 'sur les formations des différentes écoles
# ' est : 'création modules de formation' avec : 74%
# Le mot avec le plus de similarité du mot '
# ' est : 'création modules de formation' avec : 0%
# Le mot avec le plus de similarité du mot 'e projet jeux vidéo de plateforme  teddy bear
# ' est : 'planification de projets' avec : 67%
# Le mot avec le plus de similarité du mot '
# ' est : 'planification de projets' avec : 0%
# Le mot avec le plus de similarité du mot 'e projet site web mis en ligne  balithebesttour
# ' est : 'journalisme en ligne' avec : 55%
# Le mot avec le plus de similarité du mot '
# ' est : 'journalisme en ligne' avec : 0%
# Le mot avec le plus de similarité du mot 'formations
# ' est : 'formation' avec : 91%
# Le mot avec le plus de similarité du mot '
# ' est : 'formation' avec : 0%
# Le mot avec le plus de similarité du mot '20222025  bachelor 3 présentation du titre  expert
# ' est : 'graduate recruitment' avec : 64%
# Le mot avec le plus de similarité du mot 'en informatique et systéme dinformation titre rncp
# ' est : 'système dinformation' avec : 73%
# Le mot avec le plus de similarité du mot 'niveau 7
# ' est : 'autonomie' avec : 58%
# Le mot avec le plus de similarité du mot '
# ' est : 'autonomie' avec : 0%
# Le mot avec le plus de similarité du mot 'bts  2022  développeur web web mobile
# ' est : 'mobile advertising' avec : 62%
# Le mot avec le plus de similarité du mot '
# ' est : 'mobile advertising' avec : 0%
# Le mot avec le plus de similarité du mot 'bts  juillet 2020  maintenance des véhicules option
# ' est : 'contrôle des inventaires' avec : 62%
# Le mot avec le plus de similarité du mot 'a voitures particuliéres
# ' est : 'architecture' avec : 77%
