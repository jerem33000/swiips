# %%
import fitz  # PyMuPDF
import pandas as pd
from collections import Counter
from difflib import SequenceMatcher

# Chemins vers les fichiers
pdf_path1 = 'Jeremy_bourguet.pdf'
pdf_path2 = 'Alireza NIKKHAH CV - v2.pdf'
csv_path = 'skills1.csv'

# Fonction pour extraire les mots uniques d'un PDF
def extraire_mots_pdf(pdf_path):
    mots_pdf = set()  # Utilisation d'un set pour éviter les doublons
    with fitz.open(pdf_path) as pdf:
        for page in pdf:
            text = page.get_text()
            mots = text.split()  # Divise le texte en mots
            mots_pdf.update(mots)
    return mots_pdf

# Extraire les mots des deux PDFs
mots_pdf1 = extraire_mots_pdf(pdf_path1)
mots_pdf2 = extraire_mots_pdf(pdf_path2)

# Charger le fichier CSV et extraire les mots de la colonne ciblée
df = pd.read_csv(csv_path)
colonne_cible = 'Rédaction'  # Remplacez par le nom de la colonne cible dans le CSV
mots_csv = set(df[colonne_cible].dropna().astype(str).str.split().sum())

# Fonction pour calculer le pourcentage de similarité entre deux mots
def similarite_mots(mot1, mot2):
    return SequenceMatcher(None, mot1, mot2).ratio() * 100

# Comparer les mots des PDFs et du CSV pour la similarité
mots_ressemblants = {}
seuil_similarite = 80  # Seuil de similarité en pourcentage

for mot_pdf1 in mots_pdf1:
    for mot_pdf2 in mots_pdf2:
        similarite_pdf = similarite_mots(mot_pdf1, mot_pdf2)
        if similarite_pdf >= seuil_similarite:
            mots_ressemblants[(mot_pdf1, mot_pdf2)] = similarite_pdf

# Ajouter la comparaison avec les mots du CSV
mots_ressemblants_csv = {}

for mot_csv in mots_csv:
    for mot_pdf in mots_pdf1.union(mots_pdf2):
        similarite_csv = similarite_mots(mot_csv, mot_pdf)
        if similarite_csv >= seuil_similarite:
            mots_ressemblants_csv[(mot_csv, mot_pdf)] = similarite_csv

# Afficher les mots ressemblants entre les deux PDFs et avec le CSV
print(f"Mots avec une similarité de {seuil_similarite}% ou plus entre les deux PDFs :")
for (mot1, mot2), pourcentage in mots_ressemblants.items():
    print(f"{mot1} - {mot2} : {pourcentage:.2f}%")

print(f"\nMots avec une similarité de {seuil_similarite}% ou plus entre les PDFs et le CSV :")
for (mot_csv, mot_pdf), pourcentage in mots_ressemblants_csv.items():
    print(f"{mot_csv} - {mot_pdf} : {pourcentage:.2f}%")

# Optionnel : enregistrer les résultats dans un fichier texte
with open('mots_ressemblants_pdfs_et_csv.txt', 'w', encoding='utf-8') as f:
    f.write(f"Mots avec une similarité de {seuil_similarite}% ou plus entre les deux PDFs :\n")
    for (mot1, mot2), pourcentage in mots_ressemblants.items():
        f.write(f"{mot1} - {mot2} : {pourcentage:.2f}%\n")

    f.write(f"\nMots avec une similarité de {seuil_similarite}% ou plus entre les PDFs et le CSV :\n")
    for (mot_csv, mot_pdf), pourcentage in mots_ressemblants_csv.items():
        f.write(f"{mot_csv} - {mot_pdf} : {pourcentage:.2f}%\n")
# Out:
# Mots avec une similarité de 80% ou plus entre les deux PDFs :
# vidéo - video : 80.00%
# : - : : 100.00%
# 2025 - 2025) : 88.89%
# Projet - projet : 83.33%
# Astronomie - gastronomie : 85.71%
# système - système : 100.00%
# système - systèmes : 93.33%
# 3, - S3, : 80.00%
# Les - Les : 100.00%
# jeux - jeux : 100.00%
# PHP - PHP : 100.00%
# Mobile - mobile : 83.33%
# Expert - expert : 83.33%
# d'un - d'un : 100.00%
# d'un - d'une : 88.89%
# Java - Java : 100.00%
# des - de : 80.00%
# des - des : 100.00%
# Autonome - autonome. : 82.35%
# Autonome - autonome : 87.50%
# HTML - HTML : 100.00%
# Actuellement - Actuellement : 100.00%
# et - et : 100.00%
# en - en : 100.00%
# sur - sur : 100.00%
# du - du : 100.00%
# me - mes : 80.00%
# 2020: - 2020) : 80.00%
# le - le : 100.00%
# le - les : 80.00%
# CSS - CSS : 100.00%
# Création - Création : 100.00%
# PROFESSIONNEL - PROFESSIONELLES : 85.71%
# Formations - Formation : 94.74%
# Formations - formation : 84.21%
# d'information, - d'information : 96.30%
# d'information, - d'information. : 92.86%
# les - le : 80.00%
# les - les : 100.00%
# Travailleur - travailler : 85.71%
# pour - pour : 100.00%
# Toulouse - Toulouse : 100.00%
# R - R : 100.00%
# web - web : 100.00%
# - - - : 100.00%
# 27 - 27 : 100.00%
# Maintenance - maintenance : 90.91%
# 06 - 06 : 100.00%
# je - je : 100.00%
# Développeur - Developpeur : 90.91%
# Développeur - Développeur : 100.00%
# Développeur - Développer : 95.24%
# à - à : 100.00%
# site - site : 100.00%
# la - la : 100.00%
# formations - Formation : 84.21%
# formations - formation : 94.74%
# informatique - informatique : 100.00%
# informatique - informatiques : 96.00%
# informations - d'information : 88.00%
# informations - d'information. : 84.62%
# informations - informatiques : 80.00%
# informations - formation : 85.71%
# 2022-2025 - 2023-2025 : 88.89%
# 2022: - 2022) : 80.00%
# 2022: - 2022 : 88.89%
# de - de : 100.00%
# de - des : 80.00%
# 2022 - 2022) : 88.89%
# 2022 - 2022 : 100.00%
#
# Mots avec une similarité de 80% ou plus entre les PDFs et le CSV :
# gestion - Gestion : 85.71%
# Autonomie - Astronomie : 84.21%
# Autonomie - Autonome : 94.12%
# Autonomie - autonome : 82.35%
# recherche - recherche : 100.00%
# politique - politique : 100.00%
# au - au : 100.00%
# supervision - supervision : 100.00%
# photoshop - photoshop : 100.00%
# stratégique - stratégie : 90.00%
# d’interface - l'interface : 81.82%
# Curiosité - curiosité, : 84.21%
# Curiosité - curiosité : 88.89%
# le - le : 100.00%
# le - les : 80.00%
# alternance - d'alternance : 90.91%
# alternance - Alternance : 90.00%
# investissements - divertissement : 82.76%
# électronique - électroniques : 96.00%
# plan - plane, : 80.00%
# aux - au : 80.00%
# aux - ux : 80.00%
# besoins - besoins : 100.00%
# sécurité, - sécurité : 94.12%
# Nouveaux - nouveaux : 87.50%
# d'équipe - équipe : 85.71%
# de - de : 100.00%
# de - des : 80.00%
# Rechercher - recherche : 84.21%
# Programs - Program : 93.33%
# PHP - PHP : 100.00%
# fichiers - fichiers : 100.00%
# des - de : 80.00%
# des - des : 100.00%
# Mécatronique - électroniques : 80.00%
# Gestion - Gestion : 100.00%
# Fidélisation - modélisation : 83.33%
# Materials - material : 82.35%
# , - , : 100.00%
# Supervision - supervision : 90.91%
# entreprises - entreprise. : 90.91%
# sur - sur : 100.00%
# projects - projet : 85.71%
# contrat - contrat : 100.00%
# native - native) : 92.31%
# native - Native : 83.33%
# Bootstrap - Bootstrap : 100.00%
# diverse - diverses : 93.33%
# stratégie - stratégie : 100.00%
# Recherche - recherche : 88.89%
# Non - on : 80.00%
# client - clients, : 85.71%
# d’entreprise - entreprise. : 86.96%
# Scrum - scrum : 80.00%
# créatifs - réactif : 80.00%
# d’équipe - équipe : 85.71%
# les - le : 80.00%
# les - les : 100.00%
# Maintenance - Maintenance : 100.00%
# Maintenance - maintenance : 90.91%
# Informatique - informatiques : 88.00%
# Informatique - informatique : 91.67%
# Sécurité - sécurité : 87.50%
# Graphique - graphique : 88.89%
# formations - Formations : 90.00%
# formations - Formation : 84.21%
# formations - formations : 100.00%
# formations - informations : 90.91%
# formations - formation : 94.74%
# ne - une : 80.00%
# ligne - ligne : 100.00%
# :Gestion - Gestion : 93.33%
# équipes - équipe : 92.31%
# Code - Coder : 88.89%
# Laravel - (Laravel) : 87.50%
# Laravel - Laravel : 100.00%
# contenu - contenu : 100.00%
# avec - avec : 100.00%
# MySQL - MySQL : 100.00%
# contrats - contrat : 93.33%
# Typescript - typescript : 90.00%
# web - web : 100.00%
# prévention - présentation : 81.82%
# Contract - contrat : 80.00%
# Gastronomie - Astronomie : 85.71%
# Gastronomie - gastronomie : 90.91%
# que - que : 100.00%
# materials - material : 94.12%
# flux - flux : 100.00%
# vidéo - vidéo : 100.00%
# vidéo - video : 80.00%
# développement - développement : 100.00%
# formation, - Formations : 80.00%
# formation, - Formation : 84.21%
# formation, - formations : 90.00%
# formation, - informations : 81.82%
# formation, - formation : 94.74%
# formation, - d'information, : 83.33%
# service - services : 93.33%
# series - services : 85.71%
# Niveau - niveau : 83.33%
# as - asp : 80.00%
# as - aws : 80.00%
# alternance, - d'alternance : 86.96%
# alternance, - Alternance : 85.71%
# créatives - réactive : 82.35%
# Contrat - contrat : 85.71%
# d’investissement - divertissement : 86.67%
# Exploitation - Expiration : 81.82%
# l’entreprise - entreprise. : 86.96%
# Pet - et : 80.00%
# Presentations - présentation : 80.00%
# graphique - graphique : 100.00%
# d'entreprise - entreprise. : 86.96%
# Expert - expert : 83.33%
# Expert - Expert : 100.00%
# d'un - d'un : 100.00%
# d'un - d'une : 88.89%
# étudiants - étudiant : 94.12%
# Analysis - Analyse : 80.00%
# d'équipe, - équipe : 80.00%
# adaptation - d'adaptation : 90.91%
# titres - titre : 90.91%
# Créativité - créativité : 90.00%
# Devices - services : 80.00%
# Création - Création : 100.00%
# information - d'information : 91.67%
# information - Formation : 80.00%
# information - formations : 85.71%
# information - informations : 95.65%
# information - d'information. : 88.00%
# information - formation : 90.00%
# information - d'information, : 88.00%
# Système - système : 85.71%
# Système - systèmes : 80.00%
# Webmaster - master : 80.00%
# Réadaptation - d'adaptation : 83.33%
# Qualité - qualité : 85.71%
# Qualité - qualités : 80.00%
# réorientation - présentation : 80.00%
# Preparation - reparation : 95.24%
# Situations - situations, : 85.71%
# services - services : 100.00%
# artistes - parties : 80.00%
# qualité - qualité : 100.00%
# qualité - qualités : 93.33%
# en - en : 100.00%
# CSS - CSS : 100.00%
# SEO - SEO : 100.00%
# sites - site : 88.89%
# politiques - politique : 94.74%
# Information - d'information : 83.33%
# Information - Formation : 80.00%
# Information - formations : 85.71%
# Information - informations : 86.96%
# Information - d'information. : 80.00%
# Information - formation : 90.00%
# Information - d'information, : 80.00%
# Vidéo - vidéo : 80.00%
# restauration - reparation : 81.82%
# création - Création : 87.50%
# Java - Java : 100.00%
# opérations - Formations : 80.00%
# opérations - formations : 80.00%
# continue - continuer : 94.12%
# continue - contenu : 80.00%
# Capacité - capacité : 87.50%
# Photoshop - photoshop : 88.89%
# D - D : 100.00%
# formation - d'information : 81.82%
# formation - Formations : 84.21%
# formation - Formation : 88.89%
# formation - formations : 94.74%
# formation - informations : 85.71%
# formation - formation : 100.00%
# Politique - politique : 88.89%
# True - rue : 85.71%
# Applications - application : 86.96%
# Applications - l'application : 80.00%
# Applications - l’application : 80.00%
# Applications - applications : 91.67%
# Swift - swift : 80.00%
# Storage - Stage : 83.33%
# options - option : 92.31%
# SQL - SQL : 100.00%
# Program - Program : 100.00%
# nouveaux - nouveaux : 100.00%
# JavaScript - JavaScript : 100.00%
# Crypto - crypto : 83.33%
# Développement - développement : 92.31%
# Modélisation - modélisation : 91.67%
# about - aout : 88.89%
# Center - Centre : 83.33%
# agiles - agiles : 100.00%
# attitude - aptitude : 87.50%
# situation - situations, : 90.00%
# Formation - Formations : 94.74%
# Formation - Formation : 100.00%
# Formation - formations : 84.21%
# Formation - formation : 88.89%
# C - C : 100.00%
# Angular - angular : 85.71%
# Angular - Angular : 100.00%
# Apple - Apple : 100.00%
# Apple - apple : 80.00%
# Master - master : 83.33%
# Master - Mastere. : 85.71%
# Stratégique - stratégie : 80.00%
# d'équipes - équipe : 80.00%
# Analyser - Analyse : 93.33%
# clients - clients, : 93.33%
# Analyses - Analyse : 93.33%
# Python - python : 83.33%
# docker - Docker : 83.33%
# Drupal - drupal : 83.33%
# Project - Projet : 92.31%
# Stratégie - stratégie : 88.89%
# culture - cultures : 93.33%
# soins - besoins : 83.33%
# technologiques - technologies : 92.31%
# Service - services : 80.00%
# vie - vite : 85.71%
# Entreprise - entreprise. : 85.71%
# R - R : 100.00%
# analyse - Analyse : 85.71%
# Marché - Marché, : 92.31%
# Expertise - Expert : 80.00%
# d'une - d'un : 88.89%
# d'une - d'une : 100.00%
# Adaptation - d'adaptation : 81.82%
# Wordpress - wordpress : 88.89%
# Creation - Création : 87.50%
# pratiques - pratique : 94.12%
# d'information - d'information : 100.00%
# d'information - informations : 88.00%
# d'information - d'information. : 96.30%
# d'information - formation : 81.82%
# d'information - d'information, : 96.30%
# Cloud - cloud : 80.00%
# nouvelles - nouvelles : 100.00%
# Bon - on : 80.00%
# Web3 - Web : 85.71%
# & - & : 100.00%
# curieux - Curieux : 85.71%
# créatif - réactif : 85.71%
# Design - design : 83.33%
# pour - pour : 100.00%
# IDE - ID : 80.00%
# Analyse - Analyse : 100.00%
# l'entreprise - entreprise. : 86.96%
# parties - partie : 92.31%
# parties - parties : 100.00%
# HTML5 - HTML : 88.89%
# Diverse - diverses : 80.00%
# A - A : 100.00%
# active - réactive : 85.71%
# active - Native : 83.33%
# und - un : 80.00%
# HTML - HTML : 100.00%
# gestion, - Gestion : 80.00%
# l’information - d'information : 84.62%
# l’information - informations : 88.00%
# l’information - d'information. : 81.48%
# l’information - formation : 81.82%
# l’information - d'information, : 81.48%
# RPS - RS : 80.00%
# EFT - ET : 80.00%
# Amazon - amazon : 83.33%
# installations - installation : 96.00%
# la - la : 100.00%
# Maîtrise - Maîtrise : 100.00%
# Illustrator - illustrator : 90.91%
# Services - services : 87.50%
# Applied - Apple : 83.33%
# patients - parties : 80.00%
# dessin - design : 83.33%
# projet - projet : 100.00%
# projet - Projet : 83.33%
# données - données : 100.00%
# l'écoute - l'école : 80.00%
# mobiles - mobiles : 100.00%
# mobiles - mobile : 92.31%
# non - on : 80.00%
# à - à : 100.00%
# Appareils - appareils : 88.89%
# design - design : 100.00%
# content - contenu : 85.71%
# Préparation - reparation : 85.71%
# estratégica - stratégie : 80.00%
# mobile - mobiles : 92.31%
# mobile - Mobile : 83.33%
# mobile - mobile : 100.00%
# holistique - politique : 84.21%
# 2023 - 2023) : 88.89%
# vuejs - vueJs : 80.00%
# et - et : 100.00%
# Agronomie - Astronomie : 84.21%
# Agronomie - gastronomie : 80.00%
# Technologies - technologies : 91.67%
# Web - Web, : 85.71%
# Web - Web : 100.00%
# - - - : 100.00%
# API - AI : 80.00%
# stage - Stage : 80.00%
# sécurité - sécurité : 100.00%
# development - développement : 83.33%
# bases - base : 88.89%
# informatique - informatiques : 96.00%
# informatique - informatique : 100.00%
# Cover - Coder : 80.00%
# créative - réactive : 87.50%
# culturels - cultures : 94.12%
# travail - travailler : 82.35%
# Video - video : 80.00%
# Script - script : 83.33%
# installation - installation : 100.00%
# du - du : 100.00%
# Gestión - Gestion : 85.71%
# Stratégies - stratégie : 84.21%
# projets - projet : 92.31%
# domaine - domaine : 100.00%
# contenus - contenu : 93.33%
# Culture - cultures : 80.00%
# Stage - Stage : 100.00%
# mobilisation - mobilisant : 81.82%
# mobilisation - modélisation : 83.33%
# Proactive - réactive : 82.35%
# logiciels - logiciels : 100.00%
# Mobile - Mobile : 100.00%
# Mobile - mobile : 83.33%
# Systèmes - système : 80.00%
# Systèmes - systèmes : 87.50%
# numérique - numerique, : 84.21%
# un - une : 80.00%
# un - un : 100.00%
# Cuisiner - cuisine : 80.00%
# Réactivité - créativité : 80.00%
# Logiciel - logiciels : 82.35%
# Traitement - rapidement : 80.00%
# Présentations - présentation : 88.00%
# Technologie - technologies : 86.96%
# d’équipes - équipe : 80.00%
# préparation - reparation : 85.71%
# Politiques - politique : 84.21%
# Méthodes - méthodes : 87.50%

# %%
import json
from pdfminer.high_level import extract_text
from fuzzywuzzy import fuzz

# Charger le fichier JSON avec encodage UTF-8
def load_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data

# Extraire le texte du fichier PDF
def extract_text_from_pdf(file_path):
    text = extract_text(file_path)
    return text

# Extraire tous les mots du JSON (en supposant que le JSON est un dictionnaire imbriqué)
def extract_words_from_json(data):
    words = []
    def extract_recursive(obj):
        if isinstance(obj, dict):
            for value in obj.values():
                extract_recursive(value)
        elif isinstance(obj, list):
            for item in obj:
                extract_recursive(item)
        elif isinstance(obj, str):
            words.extend(obj.split())
    
    extract_recursive(data)
    return words

# Comparer chaque mot du JSON et du PDF en utilisant FuzzyWuzzy
def compare_words(json_words, pdf_words, threshold=80):
    similar_words = []
    for json_word in json_words:
        for pdf_word in pdf_words:
            similarity = fuzz.ratio(json_word, pdf_word)
            if similarity >= threshold:
                similar_words.append((json_word, pdf_word, similarity))
    return similar_words

# Main
if __name__ == "__main__":
    # Charger les fichiers
    json_data = load_json("fichier_json.json")
    pdf_text = extract_text_from_pdf("Alireza NIKKHAH CV - v2.pdf")
    
    # Extraire les mots des fichiers PDF et JSON
    json_words = extract_words_from_json(json_data)
    pdf_words = pdf_text.split()

    # Comparaison de chaque mot entre JSON et PDF
    similar_words = compare_words(json_words, pdf_words)
    print("Similarité trouvée entre les mots du JSON et du PDF:")
    for json_word, pdf_word, similarity in similar_words:
        print(f"Mot JSON: '{json_word}' - Mot PDF: '{pdf_word}' - Similarité: {similarity}%")
# Out:
# Similarité trouvée entre les mots du JSON et du PDF:
# Mot JSON: 'PHP' - Mot PDF: 'PHP' - Similarité: 100%
# Mot JSON: 'HTML' - Mot PDF: 'HTML' - Similarité: 100%
# Mot JSON: 'd'équipe' - Mot PDF: 'équipe' - Similarité: 86%

# %%
import json
from pdfminer.high_level import extract_text
from fuzzywuzzy import fuzz

# Charger le fichier JSON avec encodage UTF-8
def load_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data

# Extraire le texte du fichier PDF
def extract_text_from_pdf(file_path):
    text = extract_text(file_path)
    return text

# Extraire tous les mots du JSON (en supposant que le JSON est un dictionnaire imbriqué)
def extract_words_from_json(data):
    words = []
    def extract_recursive(obj):
        if isinstance(obj, dict):
            for value in obj.values():
                extract_recursive(value)
        elif isinstance(obj, list):
            for item in obj:
                extract_recursive(item)
        elif isinstance(obj, str):
            words.extend(obj.split())
    
    extract_recursive(data)
    return words

# Comparer chaque mot du JSON avec chaque mot du PDF en utilisant FuzzyWuzzy (seulement ceux supérieurs à 80%)
def compare_words(json_words, pdf_words, threshold=60):
    word_similarities = []
    for json_word in json_words:
        for pdf_word in pdf_words:
            similarity = fuzz.ratio(json_word, pdf_word)
            if similarity >= threshold:
                word_similarities.append((json_word, pdf_word, similarity))
    return word_similarities

# Main
if __name__ == "__main__":
    # Charger les fichiers
    json_data = load_json("fichier_json.json")
    pdf_text = extract_text_from_pdf("Alireza NIKKHAH CV - v2.pdf")
    
    # Extraire les mots des fichiers PDF et JSON
    json_words = extract_words_from_json(json_data)
    pdf_words = pdf_text.split()

    # Comparaison de chaque mot entre JSON et PDF
    word_similarities = compare_words(json_words, pdf_words)
    print("Similarité (supérieure à 80%) entre chaque mot du JSON et du PDF:")
    for json_word, pdf_word, similarity in word_similarities:
        print(f"Mot JSON: '{json_word}' - Mot PDF: '{pdf_word}' - Similarité: {similarity}%")
# Out:
# Similarité (supérieure à 80%) entre chaque mot du JSON et du PDF:
# Mot JSON: 'Javascript' - Mot PDF: 'Java' - Similarité: 57%
# Mot JSON: 'Javascript' - Mot PDF: 'Java' - Similarité: 57%
# Mot JSON: 'Javascript' - Mot PDF: 'python' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'flask' - Similarité: 27%
# Mot JSON: 'Javascript' - Mot PDF: 'rust' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'rail' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'bootstarp' - Similarité: 32%
# Mot JSON: 'Javascript' - Mot PDF: 'vueJs' - Similarité: 27%
# Mot JSON: 'Javascript' - Mot PDF: 'angular' - Similarité: 35%
# Mot JSON: 'Javascript' - Mot PDF: 'material' - Similarité: 33%
# Mot JSON: 'Javascript' - Mot PDF: 'rigoureux' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'scrum' - Similarité: 40%
# Mot JSON: 'Javascript' - Mot PDF: 'astro' - Similarité: 40%
# Mot JSON: 'Javascript' - Mot PDF: 'wordpress' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'drupal' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'passioné' - Similarité: 33%
# Mot JSON: 'Javascript' - Mot PDF: 'senior' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'swift' - Similarité: 40%
# Mot JSON: 'Javascript' - Mot PDF: 'swift' - Similarité: 40%
# Mot JSON: 'Javascript' - Mot PDF: 'apple' - Similarité: 27%
# Mot JSON: 'Javascript' - Mot PDF: 'android' - Similarité: 35%
# Mot JSON: 'Javascript' - Mot PDF: 'vscode' - Similarité: 38%
# Mot JSON: 'Javascript' - Mot PDF: 'vite' - Similarité: 43%
# Mot JSON: 'Javascript' - Mot PDF: 'aws' - Similarité: 31%
# Mot JSON: 'Javascript' - Mot PDF: 'azure' - Similarité: 27%
# Mot JSON: 'Javascript' - Mot PDF: 'amazon' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'services' - Similarité: 33%
# Mot JSON: 'Javascript' - Mot PDF: 'mariaDb' - Similarité: 35%
# Mot JSON: 'Javascript' - Mot PDF: 'apache' - Similarité: 38%
# Mot JSON: 'Javascript' - Mot PDF: 'expressJs' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'alpine' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'photoshop' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'illustrator' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'unity' - Similarité: 27%
# Mot JSON: 'Javascript' - Mot PDF: 'asp' - Similarité: 46%
# Mot JSON: 'Javascript' - Mot PDF: 'design' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'typescript' - Similarité: 60%
# Mot JSON: 'Javascript' - Mot PDF: 'fullstack' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'master' - Similarité: 38%
# Mot JSON: 'Javascript' - Mot PDF: 'bac+5' - Similarité: 27%
# Mot JSON: 'Javascript' - Mot PDF: 'bac+4' - Similarité: 27%
# Mot JSON: 'Javascript' - Mot PDF: 'autonome' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: 'polyvalent' - Similarité: 30%
# Mot JSON: 'Javascript' - Mot PDF: 'test' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'jest' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'toolkit' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'recoil' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'réactif' - Similarité: 35%
# Mot JSON: 'Javascript' - Mot PDF: 'curiosité' - Similarité: 42%
# Mot JSON: 'Javascript' - Mot PDF: 'crypto' - Similarité: 50%
# Mot JSON: 'Javascript' - Mot PDF: 'pearl' - Similarité: 27%
# Mot JSON: 'Javascript' - Mot PDF: 'script' - Similarité: 75%
# Mot JSON: 'Javascript' - Mot PDF: 'étudiant' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: 'développement' - Similarité: 26%
# Mot JSON: 'Javascript' - Mot PDF: 'suis' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'recherche' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'contrat' - Similarité: 35%
# Mot JSON: 'Javascript' - Mot PDF: 'd'alternance' - Similarité: 27%
# Mot JSON: 'Javascript' - Mot PDF: 'période' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'afin' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'préparer' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: 'diplôme' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'd'expert' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: 'Formation' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'expert' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'système' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: '(oct' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'sept' - Similarité: 43%
# Mot JSON: 'Javascript' - Mot PDF: 'Analyse' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'besoins' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'clients,' - Similarité: 33%
# Mot JSON: 'Javascript' - Mot PDF: 'définition' - Similarité: 20%
# Mot JSON: 'Javascript' - Mot PDF: 'stratégie' - Similarité: 32%
# Mot JSON: 'Javascript' - Mot PDF: 'systèmes' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: 'qualités' - Similarité: 33%
# Mot JSON: 'Javascript' - Mot PDF: 'd'infrastructure,' - Similarité: 30%
# Mot JSON: 'Javascript' - Mot PDF: 'politique' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'sécurité' - Similarité: 56%
# Mot JSON: 'Javascript' - Mot PDF: 'supervision' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'projet' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'principales' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'sont' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'curiosité,' - Similarité: 40%
# Mot JSON: 'Javascript' - Mot PDF: 'capacité' - Similarité: 56%
# Mot JSON: 'Javascript' - Mot PDF: 'd'adaptation' - Similarité: 36%
# Mot JSON: 'Javascript' - Mot PDF: 'aptitude' - Similarité: 33%
# Mot JSON: 'Javascript' - Mot PDF: 'travailler' - Similarité: 40%
# Mot JSON: 'Javascript' - Mot PDF: 'équipe' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'manière' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'autonome.' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: '@alirezanikkhah' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: '@alirezanikkhah1375' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'Opquast' - Similarité: 35%
# Mot JSON: 'Javascript' - Mot PDF: 'Maîtrise' - Similarité: 33%
# Mot JSON: 'Javascript' - Mot PDF: 'qualité' - Similarité: 35%
# Mot JSON: 'Javascript' - Mot PDF: 'projet' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'Expiration' - Similarité: 20%
# Mot JSON: 'Javascript' - Mot PDF: 'Mai' - Similarité: 31%
# Mot JSON: 'Javascript' - Mot PDF: 'Simplon' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'projet' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'mobilisant' - Similarité: 20%
# Mot JSON: 'Javascript' - Mot PDF: 'agiles' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'React' - Similarité: 40%
# Mot JSON: 'Javascript' - Mot PDF: 'Bootstrap' - Similarité: 32%
# Mot JSON: 'Javascript' - Mot PDF: 'React' - Similarité: 40%
# Mot JSON: 'Javascript' - Mot PDF: 'Native' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'Laravel' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'Android' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'Docker' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'Angular' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'Gitlab' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'découvrir' - Similarité: 32%
# Mot JSON: 'Javascript' - Mot PDF: 'nouveaux' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: 'endroits' - Similarité: 33%
# Mot JSON: 'Javascript' - Mot PDF: 'nouvelles' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'cultures' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: 'cuisine' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'j'aime' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'créativité' - Similarité: 40%
# Mot JSON: 'Javascript' - Mot PDF: 'permet' - Similarité: 25%
# Mot JSON: 'Javascript' - Mot PDF: 'gastronomie' - Similarité: 38%
# Mot JSON: 'Javascript' - Mot PDF: 'pratique' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: 'régulièrement' - Similarité: 26%
# Mot JSON: 'Javascript' - Mot PDF: 'Formation' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'Simplon' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'sept' - Similarité: 43%
# Mot JSON: 'Javascript' - Mot PDF: 'Développer' - Similarité: 20%
# Mot JSON: 'Javascript' - Mot PDF: 'parties' - Similarité: 35%
# Mot JSON: 'Javascript' - Mot PDF: 'front-end' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'back-end' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: 'application' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'Formation' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'Foundation' - Similarité: 20%
# Mot JSON: 'Javascript' - Mot PDF: 'Simplon,' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: '(sept' - Similarité: 40%
# Mot JSON: 'Javascript' - Mot PDF: 'Création' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: 'l’application' - Similarité: 26%
# Mot JSON: 'Javascript' - Mot PDF: '(swift' - Similarité: 38%
# Mot JSON: 'Javascript' - Mot PDF: 'Baccaleauréat' - Similarité: 35%
# Mot JSON: 'Javascript' - Mot PDF: 'scientifique' - Similarité: 36%
# Mot JSON: 'Javascript' - Mot PDF: 'Alternance' - Similarité: 20%
# Mot JSON: 'Javascript' - Mot PDF: 'numerique,' - Similarité: 20%
# Mot JSON: 'Javascript' - Mot PDF: '(oct' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'sept' - Similarité: 43%
# Mot JSON: 'Javascript' - Mot PDF: 'Concevoir' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'maquette' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: 'l'application' - Similarité: 26%
# Mot JSON: 'Javascript' - Mot PDF: 'Développer' - Similarité: 20%
# Mot JSON: 'Javascript' - Mot PDF: 'applications' - Similarité: 27%
# Mot JSON: 'Javascript' - Mot PDF: 'Fullstack' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: '(Laravel)' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'Développer' - Similarité: 20%
# Mot JSON: 'Javascript' - Mot PDF: 'applications' - Similarité: 27%
# Mot JSON: 'Javascript' - Mot PDF: 'hybrides' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: '(React' - Similarité: 38%
# Mot JSON: 'Javascript' - Mot PDF: 'native)' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'Marché,' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: '(mai' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'aout' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'Concevoir' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'maquette' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: 'site' - Similarité: 43%
# Mot JSON: 'Javascript' - Mot PDF: 'Développer' - Similarité: 20%
# Mot JSON: 'Javascript' - Mot PDF: 'graphique' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'site' - Similarité: 43%
# Mot JSON: 'Javascript' - Mot PDF: 'tailwind,' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'amplify' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'Développer' - Similarité: 20%
# Mot JSON: 'Javascript' - Mot PDF: 'GraphQL' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'base' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'appsync)' - Similarité: 33%
# Mot JSON: 'Javascript' - Mot PDF: 'Gestion' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'stockage' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: 'fichiers' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: 'auth)' - Similarité: 27%
# Mot JSON: 'Javascript' - Mot PDF: 'formation' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'Aformac,' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: '(mai' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'contenu' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'avec' - Similarité: 43%
# Mot JSON: 'Javascript' - Mot PDF: 'réactive' - Similarité: 33%
# Mot JSON: 'Javascript' - Mot PDF: 'avec' - Similarité: 43%
# Mot JSON: 'Javascript' - Mot PDF: 'Technicien' - Similarité: 20%
# Mot JSON: 'Javascript' - Mot PDF: 'MicroRezo,' - Similarité: 20%
# Mot JSON: 'Javascript' - Mot PDF: '(oct' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'installation' - Similarité: 27%
# Mot JSON: 'Javascript' - Mot PDF: 'logiciels' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'maintenance' - Similarité: 29%
# Mot JSON: 'Javascript' - Mot PDF: 'reparation' - Similarité: 30%
# Mot JSON: 'Javascript' - Mot PDF: 'sur' - Similarité: 31%
# Mot JSON: 'Javascript' - Mot PDF: 'diverses' - Similarité: 22%
# Mot JSON: 'Javascript' - Mot PDF: 'appareils' - Similarité: 42%
# Mot JSON: 'Javascript' - Mot PDF: 'électroniques' - Similarité: 26%
# Mot JSON: 'Javascript' - Mot PDF: 'video' - Similarité: 27%
# Mot JSON: 'Javascript' - Mot PDF: 'partie' - Similarité: 38%
# Mot JSON: 'Javascript' - Mot PDF: 'loisirs' - Similarité: 24%
# Mot JSON: 'Javascript' - Mot PDF: 'réguliers' - Similarité: 21%
# Mot JSON: 'Javascript' - Mot PDF: 'laptops...)' - Similarité: 29%
# Mot JSON: 'PHP' - Mot PDF: 'DEVELOPPEUR' - Similarité: 29%
# Mot JSON: 'PHP' - Mot PDF: 'PROFIL' - Similarité: 22%
# Mot JSON: 'PHP' - Mot PDF: 'HARD' - Similarité: 29%
# Mot JSON: 'PHP' - Mot PDF: 'PHP' - Similarité: 100%
# Mot JSON: 'PHP' - Mot PDF: 'Program' - Similarité: 20%
# Mot JSON: 'PHP' - Mot PDF: 'l'API' - Similarité: 25%
# Mot JSON: 'PHP' - Mot PDF: 'HTML' - Similarité: 29%
# Mot JSON: 'HTML' - Mot PDF: 'ET' - Similarité: 33%
# Mot JSON: 'HTML' - Mot PDF: 'MOBILE' - Similarité: 40%
# Mot JSON: 'HTML' - Mot PDF: 'PROFIL' - Similarité: 20%
# Mot JSON: 'HTML' - Mot PDF: 'Mes' - Similarité: 29%
# Mot JSON: 'HTML' - Mot PDF: 'Mai' - Similarité: 29%
# Mot JSON: 'HTML' - Mot PDF: 'TL5GK1' - Similarité: 40%
# Mot JSON: 'HTML' - Mot PDF: 'HARD' - Similarité: 25%
# Mot JSON: 'HTML' - Mot PDF: 'SKILLS' - Similarité: 20%
# Mot JSON: 'HTML' - Mot PDF: 'HTML/CSS' - Similarité: 67%
# Mot JSON: 'HTML' - Mot PDF: 'PHP' - Similarité: 29%
# Mot JSON: 'HTML' - Mot PDF: 'MySQL' - Similarité: 44%
# Mot JSON: 'HTML' - Mot PDF: 'CENTRE' - Similarité: 20%
# Mot JSON: 'HTML' - Mot PDF: 'Lycée' - Similarité: 22%
# Mot JSON: 'HTML' - Mot PDF: 'Totem' - Similarité: 22%
# Mot JSON: 'HTML' - Mot PDF: 'Tous' - Similarité: 25%
# Mot JSON: 'HTML' - Mot PDF: 'HTML' - Similarité: 100%
# Mot JSON: 'HTML' - Mot PDF: 'Les' - Similarité: 29%
# Mot JSON: 'Esprit' - Mot PDF: 'EE' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'python' - Similarité: 33%
# Mot JSON: 'Esprit' - Mot PDF: 'rust' - Similarité: 40%
# Mot JSON: 'Esprit' - Mot PDF: 'ruby' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'rail' - Similarité: 40%
# Mot JSON: 'Esprit' - Mot PDF: 'bootstarp' - Similarité: 27%
# Mot JSON: 'Esprit' - Mot PDF: 'material' - Similarité: 29%
# Mot JSON: 'Esprit' - Mot PDF: 'rigoureux' - Similarité: 27%
# Mot JSON: 'Esprit' - Mot PDF: 'scrum' - Similarité: 36%
# Mot JSON: 'Esprit' - Mot PDF: 'astro' - Similarité: 36%
# Mot JSON: 'Esprit' - Mot PDF: 'nuxt' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'cms' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'wordpress' - Similarité: 27%
# Mot JSON: 'Esprit' - Mot PDF: 'passioné' - Similarité: 29%
# Mot JSON: 'Esprit' - Mot PDF: 'senior' - Similarité: 33%
# Mot JSON: 'Esprit' - Mot PDF: 'ios' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'swift' - Similarité: 55%
# Mot JSON: 'Esprit' - Mot PDF: 'ui' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'swift' - Similarité: 55%
# Mot JSON: 'Esprit' - Mot PDF: 'android' - Similarité: 31%
# Mot JSON: 'Esprit' - Mot PDF: 'vite' - Similarité: 40%
# Mot JSON: 'Esprit' - Mot PDF: 'aws' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'services' - Similarité: 43%
# Mot JSON: 'Esprit' - Mot PDF: 'sql' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'mariaDb' - Similarité: 31%
# Mot JSON: 'Esprit' - Mot PDF: 'expressJs' - Similarité: 27%
# Mot JSON: 'Esprit' - Mot PDF: 'express' - Similarité: 31%
# Mot JSON: 'Esprit' - Mot PDF: 'alpine' - Similarité: 33%
# Mot JSON: 'Esprit' - Mot PDF: 'photoshop' - Similarité: 27%
# Mot JSON: 'Esprit' - Mot PDF: 'illustrator' - Similarité: 35%
# Mot JSON: 'Esprit' - Mot PDF: 'unity' - Similarité: 36%
# Mot JSON: 'Esprit' - Mot PDF: '.net' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'asp' - Similarité: 44%
# Mot JSON: 'Esprit' - Mot PDF: 'ui' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'design' - Similarité: 33%
# Mot JSON: 'Esprit' - Mot PDF: 'typescript' - Similarité: 50%
# Mot JSON: 'Esprit' - Mot PDF: 'SEO' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'fullstack' - Similarité: 27%
# Mot JSON: 'Esprit' - Mot PDF: 'master' - Similarité: 33%
# Mot JSON: 'Esprit' - Mot PDF: 'polyvalent' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'test' - Similarité: 40%
# Mot JSON: 'Esprit' - Mot PDF: 'jest' - Similarité: 40%
# Mot JSON: 'Esprit' - Mot PDF: 'toolkit' - Similarité: 31%
# Mot JSON: 'Esprit' - Mot PDF: 'recoil' - Similarité: 33%
# Mot JSON: 'Esprit' - Mot PDF: 'réactif' - Similarité: 31%
# Mot JSON: 'Esprit' - Mot PDF: 'curiosité' - Similarité: 40%
# Mot JSON: 'Esprit' - Mot PDF: 'crypto' - Similarité: 33%
# Mot JSON: 'Esprit' - Mot PDF: 'pearl' - Similarité: 36%
# Mot JSON: 'Esprit' - Mot PDF: 'script' - Similarité: 67%
# Mot JSON: 'Esprit' - Mot PDF: 'WEB' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'ET' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'WEB' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'EN' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'étudiant' - Similarité: 29%
# Mot JSON: 'Esprit' - Mot PDF: 'développement' - Similarité: 21%
# Mot JSON: 'Esprit' - Mot PDF: 'suis' - Similarité: 40%
# Mot JSON: 'Esprit' - Mot PDF: 'contrat' - Similarité: 31%
# Mot JSON: 'Esprit' - Mot PDF: 'pour' - Similarité: 40%
# Mot JSON: 'Esprit' - Mot PDF: 'période' - Similarité: 46%
# Mot JSON: 'Esprit' - Mot PDF: 'afin' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'préparer' - Similarité: 29%
# Mot JSON: 'Esprit' - Mot PDF: 'd'expert' - Similarité: 43%
# Mot JSON: 'Esprit' - Mot PDF: 'Formation' - Similarité: 27%
# Mot JSON: 'Esprit' - Mot PDF: 'expert' - Similarité: 50%
# Mot JSON: 'Esprit' - Mot PDF: 'informatique' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'système' - Similarité: 31%
# Mot JSON: 'Esprit' - Mot PDF: 'd'information' - Similarité: 21%
# Mot JSON: 'Esprit' - Mot PDF: '(oct' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'sept' - Similarité: 60%
# Mot JSON: 'Esprit' - Mot PDF: 'des' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'besoins' - Similarité: 31%
# Mot JSON: 'Esprit' - Mot PDF: 'clients,' - Similarité: 29%
# Mot JSON: 'Esprit' - Mot PDF: 'définition' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'stratégie' - Similarité: 40%
# Mot JSON: 'Esprit' - Mot PDF: 'modélisation' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'informatique' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'systèmes' - Similarité: 29%
# Mot JSON: 'Esprit' - Mot PDF: 'd'information.' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'Mes' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'qualités' - Similarité: 29%
# Mot JSON: 'Esprit' - Mot PDF: 'd'infrastructure,' - Similarité: 26%
# Mot JSON: 'Esprit' - Mot PDF: 'politique' - Similarité: 40%
# Mot JSON: 'Esprit' - Mot PDF: 'sécurité' - Similarité: 57%
# Mot JSON: 'Esprit' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'supervision' - Similarité: 47%
# Mot JSON: 'Esprit' - Mot PDF: 'projet' - Similarité: 50%
# Mot JSON: 'Esprit' - Mot PDF: 'principales' - Similarité: 35%
# Mot JSON: 'Esprit' - Mot PDF: 'sont' - Similarité: 40%
# Mot JSON: 'Esprit' - Mot PDF: 'curiosité,' - Similarité: 38%
# Mot JSON: 'Esprit' - Mot PDF: 'capacité' - Similarité: 43%
# Mot JSON: 'Esprit' - Mot PDF: 'd'adaptation' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'aptitude' - Similarité: 43%
# Mot JSON: 'Esprit' - Mot PDF: 'travailler' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'rue' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'Opquast' - Similarité: 31%
# Mot JSON: 'Esprit' - Mot PDF: 'Maîtrise' - Similarité: 29%
# Mot JSON: 'Esprit' - Mot PDF: 'qualité' - Similarité: 31%
# Mot JSON: 'Esprit' - Mot PDF: 'projet' - Similarité: 50%
# Mot JSON: 'Esprit' - Mot PDF: 'Expiration' - Similarité: 50%
# Mot JSON: 'Esprit' - Mot PDF: 'Mai' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'projet' - Similarité: 50%
# Mot JSON: 'Esprit' - Mot PDF: 'mobilisant' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'les' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'Express' - Similarité: 46%
# Mot JSON: 'Esprit' - Mot PDF: 'Bootstrap' - Similarité: 27%
# Mot JSON: 'Esprit' - Mot PDF: 'Next' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'Android' - Similarité: 31%
# Mot JSON: 'Esprit' - Mot PDF: 'Amplify' - Similarité: 31%
# Mot JSON: 'Esprit' - Mot PDF: 'Gitlab' - Similarité: 33%
# Mot JSON: 'Esprit' - Mot PDF: 'Explorer' - Similarité: 43%
# Mot JSON: 'Esprit' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'découvrir' - Similarité: 27%
# Mot JSON: 'Esprit' - Mot PDF: 'endroits' - Similarité: 43%
# Mot JSON: 'Esprit' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'cuisine' - Similarité: 31%
# Mot JSON: 'Esprit' - Mot PDF: 'fréquemment' - Similarité: 24%
# Mot JSON: 'Esprit' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'créativité' - Similarité: 38%
# Mot JSON: 'Esprit' - Mot PDF: 'permet' - Similarité: 50%
# Mot JSON: 'Esprit' - Mot PDF: 'gastronomie' - Similarité: 35%
# Mot JSON: 'Esprit' - Mot PDF: 'pratique' - Similarité: 43%
# Mot JSON: 'Esprit' - Mot PDF: 'régulièrement' - Similarité: 32%
# Mot JSON: 'Esprit' - Mot PDF: 'Formation' - Similarité: 27%
# Mot JSON: 'Esprit' - Mot PDF: 'Developpeur' - Similarité: 24%
# Mot JSON: 'Esprit' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'sept' - Similarité: 60%
# Mot JSON: 'Esprit' - Mot PDF: 'Développer' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'les' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'parties' - Similarité: 46%
# Mot JSON: 'Esprit' - Mot PDF: 'front-end' - Similarité: 27%
# Mot JSON: 'Esprit' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'application' - Similarité: 35%
# Mot JSON: 'Esprit' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'Formation' - Similarité: 27%
# Mot JSON: 'Esprit' - Mot PDF: '(sept' - Similarité: 55%
# Mot JSON: 'Esprit' - Mot PDF: 'Création' - Similarité: 29%
# Mot JSON: 'Esprit' - Mot PDF: 'l’application' - Similarité: 32%
# Mot JSON: 'Esprit' - Mot PDF: '(swift' - Similarité: 50%
# Mot JSON: 'Esprit' - Mot PDF: 'Baccaleauréat' - Similarité: 21%
# Mot JSON: 'Esprit' - Mot PDF: 'scientifique' - Similarité: 33%
# Mot JSON: 'Esprit' - Mot PDF: 'Iran' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'Développeur' - Similarité: 24%
# Mot JSON: 'Esprit' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'numerique,' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: '(oct' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'sept' - Similarité: 60%
# Mot JSON: 'Esprit' - Mot PDF: 'l'application' - Similarité: 32%
# Mot JSON: 'Esprit' - Mot PDF: 'Développer' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'des' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'applications' - Similarité: 33%
# Mot JSON: 'Esprit' - Mot PDF: 'Fullstack' - Similarité: 27%
# Mot JSON: 'Esprit' - Mot PDF: 'Développer' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'des' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'applications' - Similarité: 33%
# Mot JSON: 'Esprit' - Mot PDF: 'hybrides' - Similarité: 29%
# Mot JSON: 'Esprit' - Mot PDF: 'Développeur' - Similarité: 24%
# Mot JSON: 'Esprit' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'Tous' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: '(mai' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'aout' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'site' - Similarité: 60%
# Mot JSON: 'Esprit' - Mot PDF: 'Développer' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'l'interface' - Similarité: 24%
# Mot JSON: 'Esprit' - Mot PDF: 'graphique' - Similarité: 27%
# Mot JSON: 'Esprit' - Mot PDF: 'site' - Similarité: 60%
# Mot JSON: 'Esprit' - Mot PDF: 'amplify' - Similarité: 31%
# Mot JSON: 'Esprit' - Mot PDF: 'Développer' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'base' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: '(Aws' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'Gestion' - Similarité: 31%
# Mot JSON: 'Esprit' - Mot PDF: 'stockage' - Similarité: 29%
# Mot JSON: 'Esprit' - Mot PDF: 'des' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: '(Aws' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'formation' - Similarité: 27%
# Mot JSON: 'Esprit' - Mot PDF: '(mai' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'page' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'page' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'réactive' - Similarité: 29%
# Mot JSON: 'Esprit' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'informatique' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: '(oct' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'installation' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'informatiques' - Similarité: 21%
# Mot JSON: 'Esprit' - Mot PDF: 'maintenance' - Similarité: 24%
# Mot JSON: 'Esprit' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Esprit' - Mot PDF: 'reparation' - Similarité: 38%
# Mot JSON: 'Esprit' - Mot PDF: 'sur' - Similarité: 44%
# Mot JSON: 'Esprit' - Mot PDF: 'appareils' - Similarité: 40%
# Mot JSON: 'Esprit' - Mot PDF: 'électroniques' - Similarité: 21%
# Mot JSON: 'Esprit' - Mot PDF: 'Les' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'font' - Similarité: 20%
# Mot JSON: 'Esprit' - Mot PDF: 'partie' - Similarité: 50%
# Mot JSON: 'Esprit' - Mot PDF: 'mes' - Similarité: 22%
# Mot JSON: 'Esprit' - Mot PDF: 'loisirs' - Similarité: 31%
# Mot JSON: 'Esprit' - Mot PDF: 'réguliers' - Similarité: 27%
# Mot JSON: 'Esprit' - Mot PDF: 'laptops...)' - Similarité: 24%
# Mot JSON: 'd'équipe' - Mot PDF: 'vueJs' - Similarité: 31%
# Mot JSON: 'd'équipe' - Mot PDF: 'rigoureux' - Similarité: 24%
# Mot JSON: 'd'équipe' - Mot PDF: 'wordpress' - Similarité: 35%
# Mot JSON: 'd'équipe' - Mot PDF: 'drupal' - Similarité: 43%
# Mot JSON: 'd'équipe' - Mot PDF: 'ui' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'apple' - Similarité: 31%
# Mot JSON: 'd'équipe' - Mot PDF: 'android' - Similarité: 27%
# Mot JSON: 'd'équipe' - Mot PDF: 'xcode' - Similarité: 31%
# Mot JSON: 'd'équipe' - Mot PDF: 'vscode' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'vite' - Similarité: 33%
# Mot JSON: 'd'équipe' - Mot PDF: 'azure' - Similarité: 31%
# Mot JSON: 'd'équipe' - Mot PDF: 'services' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'apache' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'nodeJS' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'expressJs' - Similarité: 24%
# Mot JSON: 'd'équipe' - Mot PDF: 'express' - Similarité: 27%
# Mot JSON: 'd'équipe' - Mot PDF: 'node' - Similarité: 33%
# Mot JSON: 'd'équipe' - Mot PDF: 'deno' - Similarité: 33%
# Mot JSON: 'd'équipe' - Mot PDF: 'alpine' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: '3d' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'unity' - Similarité: 31%
# Mot JSON: 'd'équipe' - Mot PDF: 'ux' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'ui' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'design' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'typescript' - Similarité: 22%
# Mot JSON: 'd'équipe' - Mot PDF: 'autonome' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'polyvalent' - Similarité: 22%
# Mot JSON: 'd'équipe' - Mot PDF: 'redux' - Similarité: 31%
# Mot JSON: 'd'équipe' - Mot PDF: 'query' - Similarité: 46%
# Mot JSON: 'd'équipe' - Mot PDF: 'réactif' - Similarité: 27%
# Mot JSON: 'd'équipe' - Mot PDF: 'curiosité' - Similarité: 24%
# Mot JSON: 'd'équipe' - Mot PDF: 'pearl' - Similarité: 31%
# Mot JSON: 'd'équipe' - Mot PDF: 'script' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'Alireza' - Similarité: 27%
# Mot JSON: 'd'équipe' - Mot PDF: 'D'' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'Actuellement' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'étudiant' - Similarité: 38%
# Mot JSON: 'd'équipe' - Mot PDF: 'en' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'développement' - Similarité: 38%
# Mot JSON: 'd'équipe' - Mot PDF: 'l'école' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'je' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'suis' - Similarité: 33%
# Mot JSON: 'd'équipe' - Mot PDF: 'd'un' - Similarité: 50%
# Mot JSON: 'd'équipe' - Mot PDF: 'd'alternance' - Similarité: 30%
# Mot JSON: 'd'équipe' - Mot PDF: 'période' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'de' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'préparer' - Similarité: 38%
# Mot JSON: 'd'équipe' - Mot PDF: 'un' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'diplôme' - Similarité: 53%
# Mot JSON: 'd'équipe' - Mot PDF: 'd'expert' - Similarité: 50%
# Mot JSON: 'd'équipe' - Mot PDF: 'en' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'expert' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'informatique' - Similarité: 30%
# Mot JSON: 'd'équipe' - Mot PDF: 'et' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'd'information' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'Toulouse' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'des' - Similarité: 36%
# Mot JSON: 'd'équipe' - Mot PDF: 'clients,' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'définition' - Similarité: 33%
# Mot JSON: 'd'équipe' - Mot PDF: 'de' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'stratégie' - Similarité: 35%
# Mot JSON: 'd'équipe' - Mot PDF: 'modélisation' - Similarité: 30%
# Mot JSON: 'd'équipe' - Mot PDF: 'informatique' - Similarité: 30%
# Mot JSON: 'd'équipe' - Mot PDF: 'et' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'd'information.' - Similarité: 27%
# Mot JSON: 'd'équipe' - Mot PDF: 'qualités' - Similarité: 38%
# Mot JSON: 'd'équipe' - Mot PDF: 'd'infrastructure,' - Similarité: 32%
# Mot JSON: 'd'équipe' - Mot PDF: 'politique' - Similarité: 35%
# Mot JSON: 'd'équipe' - Mot PDF: 'de' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'sécurité' - Similarité: 38%
# Mot JSON: 'd'équipe' - Mot PDF: 'et' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'supervision' - Similarité: 32%
# Mot JSON: 'd'équipe' - Mot PDF: 'du' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'projet' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'principales' - Similarité: 32%
# Mot JSON: 'd'équipe' - Mot PDF: 'curiosité,' - Similarité: 22%
# Mot JSON: 'd'équipe' - Mot PDF: 'd'adaptation' - Similarité: 30%
# Mot JSON: 'd'équipe' - Mot PDF: 'et' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'aptitude' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'travailler' - Similarité: 22%
# Mot JSON: 'd'équipe' - Mot PDF: 'en' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'équipe' - Similarité: 86%
# Mot JSON: 'd'équipe' - Mot PDF: 'de' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'manière' - Similarité: 27%
# Mot JSON: 'd'équipe' - Mot PDF: 'autonome.' - Similarité: 24%
# Mot JSON: 'd'équipe' - Mot PDF: 'rue' - Similarité: 36%
# Mot JSON: 'd'équipe' - Mot PDF: 'de' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'Toulouse' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'Opquast' - Similarité: 27%
# Mot JSON: 'd'équipe' - Mot PDF: 'Maîtrise' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'de' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'qualité' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'en' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'projet' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'Simplon' - Similarité: 27%
# Mot JSON: 'd'équipe' - Mot PDF: 'Gérer' - Similarité: 31%
# Mot JSON: 'd'équipe' - Mot PDF: 'un' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'projet' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'en' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'méthodes' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'agiles' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'Express' - Similarité: 27%
# Mot JSON: 'd'équipe' - Mot PDF: 'Native' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'Android' - Similarité: 27%
# Mot JSON: 'd'équipe' - Mot PDF: 'Node' - Similarité: 33%
# Mot JSON: 'd'équipe' - Mot PDF: 'Explorer' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'et' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'découvrir' - Similarité: 47%
# Mot JSON: 'd'équipe' - Mot PDF: 'de' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'nouveaux' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'endroits' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'et' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'de' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'nouvelles' - Similarité: 24%
# Mot JSON: 'd'équipe' - Mot PDF: 'cultures' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'Je' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'cuisine' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'fréquemment' - Similarité: 42%
# Mot JSON: 'd'équipe' - Mot PDF: 'et' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'j'aime' - Similarité: 43%
# Mot JSON: 'd'équipe' - Mot PDF: 'créativité' - Similarité: 22%
# Mot JSON: 'd'équipe' - Mot PDF: 'que' - Similarité: 55%
# Mot JSON: 'd'équipe' - Mot PDF: 'permet' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'gastronomie' - Similarité: 21%
# Mot JSON: 'd'équipe' - Mot PDF: 'Je' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'pratique' - Similarité: 38%
# Mot JSON: 'd'équipe' - Mot PDF: 'régulièrement' - Similarité: 38%
# Mot JSON: 'd'équipe' - Mot PDF: 'le' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'Developpeur' - Similarité: 21%
# Mot JSON: 'd'équipe' - Mot PDF: 'et' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'mobile' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'Simplon' - Similarité: 27%
# Mot JSON: 'd'équipe' - Mot PDF: 'Toulouse' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'Développer' - Similarité: 33%
# Mot JSON: 'd'équipe' - Mot PDF: 'parties' - Similarité: 27%
# Mot JSON: 'd'équipe' - Mot PDF: 'et' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'd'une' - Similarité: 62%
# Mot JSON: 'd'équipe' - Mot PDF: 'et' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'mobile' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'Apple' - Similarité: 31%
# Mot JSON: 'd'équipe' - Mot PDF: 'Foundation' - Similarité: 22%
# Mot JSON: 'd'équipe' - Mot PDF: 'Simplon,' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'Toulouse' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'Création' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'de' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'de' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'scientifique' - Similarité: 30%
# Mot JSON: 'd'équipe' - Mot PDF: 'Lycée' - Similarité: 31%
# Mot JSON: 'd'équipe' - Mot PDF: 'Développeur' - Similarité: 32%
# Mot JSON: 'd'équipe' - Mot PDF: 'et' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'mobile' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'numerique,' - Similarité: 33%
# Mot JSON: 'd'équipe' - Mot PDF: 'Toulouse' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'maquette' - Similarité: 38%
# Mot JSON: 'd'équipe' - Mot PDF: 'de' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'mobile' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'Développer' - Similarité: 33%
# Mot JSON: 'd'équipe' - Mot PDF: 'des' - Similarité: 36%
# Mot JSON: 'd'équipe' - Mot PDF: 'Développer' - Similarité: 33%
# Mot JSON: 'd'équipe' - Mot PDF: 'des' - Similarité: 36%
# Mot JSON: 'd'équipe' - Mot PDF: 'mobiles' - Similarité: 27%
# Mot JSON: 'd'équipe' - Mot PDF: 'hybrides' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'native)' - Similarité: 27%
# Mot JSON: 'd'équipe' - Mot PDF: 'Développeur' - Similarité: 32%
# Mot JSON: 'd'équipe' - Mot PDF: 'et' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'mobile' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'au' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'Toulouse' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'maquette' - Similarité: 38%
# Mot JSON: 'd'équipe' - Mot PDF: 'du' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'site' - Similarité: 33%
# Mot JSON: 'd'équipe' - Mot PDF: 'Développer' - Similarité: 33%
# Mot JSON: 'd'équipe' - Mot PDF: 'l'interface' - Similarité: 32%
# Mot JSON: 'd'équipe' - Mot PDF: 'graphique' - Similarité: 35%
# Mot JSON: 'd'équipe' - Mot PDF: 'du' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'site' - Similarité: 33%
# Mot JSON: 'd'équipe' - Mot PDF: 'Développer' - Similarité: 33%
# Mot JSON: 'd'équipe' - Mot PDF: 'et' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'de' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'données' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'du' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'des' - Similarité: 36%
# Mot JSON: 'd'équipe' - Mot PDF: 'fichiers' - Similarité: 25%
# Mot JSON: 'd'équipe' - Mot PDF: 'de' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'Limoges' - Similarité: 27%
# Mot JSON: 'd'équipe' - Mot PDF: 'Coder' - Similarité: 31%
# Mot JSON: 'd'équipe' - Mot PDF: 'le' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'de' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'page' - Similarité: 33%
# Mot JSON: 'd'équipe' - Mot PDF: 'Créer' - Similarité: 31%
# Mot JSON: 'd'équipe' - Mot PDF: 'une' - Similarité: 36%
# Mot JSON: 'd'équipe' - Mot PDF: 'page' - Similarité: 33%
# Mot JSON: 'd'équipe' - Mot PDF: 'réactive' - Similarité: 38%
# Mot JSON: 'd'équipe' - Mot PDF: 'et' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'Technicien' - Similarité: 22%
# Mot JSON: 'd'équipe' - Mot PDF: 'informatique' - Similarité: 30%
# Mot JSON: 'd'équipe' - Mot PDF: 'MicroRezo,' - Similarité: 22%
# Mot JSON: 'd'équipe' - Mot PDF: 'Limoges' - Similarité: 27%
# Mot JSON: 'd'équipe' - Mot PDF: 'de' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'logiciels' - Similarité: 24%
# Mot JSON: 'd'équipe' - Mot PDF: 'informatiques' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'maintenance' - Similarité: 21%
# Mot JSON: 'd'équipe' - Mot PDF: 'et' - Similarité: 20%
# Mot JSON: 'd'équipe' - Mot PDF: 'diverses' - Similarité: 38%
# Mot JSON: 'd'équipe' - Mot PDF: 'appareils' - Similarité: 24%
# Mot JSON: 'd'équipe' - Mot PDF: 'électroniques' - Similarité: 38%
# Mot JSON: 'd'équipe' - Mot PDF: 'video' - Similarité: 31%
# Mot JSON: 'd'équipe' - Mot PDF: 'partie' - Similarité: 29%
# Mot JSON: 'd'équipe' - Mot PDF: 'de' - Similarité: 40%
# Mot JSON: 'd'équipe' - Mot PDF: 'réguliers' - Similarité: 47%
# Mot JSON: 'd'équipe' - Mot PDF: '(télephones,' - Similarité: 30%
# Mot JSON: 'Motivé' - Mot PDF: 'Java' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'Java' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'rust' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'on' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'rail' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'bootstarp' - Similarité: 27%
# Mot JSON: 'Motivé' - Mot PDF: 'material' - Similarité: 29%
# Mot JSON: 'Motivé' - Mot PDF: 'nuxt' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'passioné' - Similarité: 29%
# Mot JSON: 'Motivé' - Mot PDF: 'kotlin' - Similarité: 50%
# Mot JSON: 'Motivé' - Mot PDF: 'ios' - Similarité: 22%
# Mot JSON: 'Motivé' - Mot PDF: 'ui' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'android' - Similarité: 31%
# Mot JSON: 'Motivé' - Mot PDF: 'vite' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'node' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'deno' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'photoshop' - Similarité: 27%
# Mot JSON: 'Motivé' - Mot PDF: '.net' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'ui' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'typescript' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'polyvalent' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'test' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'jest' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'toolkit' - Similarité: 31%
# Mot JSON: 'Motivé' - Mot PDF: 'recoil' - Similarité: 33%
# Mot JSON: 'Motivé' - Mot PDF: 'réactif' - Similarité: 31%
# Mot JSON: 'Motivé' - Mot PDF: 'curiosité' - Similarité: 40%
# Mot JSON: 'Motivé' - Mot PDF: 'étudiant' - Similarité: 29%
# Mot JSON: 'Motivé' - Mot PDF: 'développement' - Similarité: 21%
# Mot JSON: 'Motivé' - Mot PDF: 'Ynov,' - Similarité: 36%
# Mot JSON: 'Motivé' - Mot PDF: 'suis' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'contrat' - Similarité: 31%
# Mot JSON: 'Motivé' - Mot PDF: 'pour' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'afin' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'Formation' - Similarité: 40%
# Mot JSON: 'Motivé' - Mot PDF: 'informatique' - Similarité: 33%
# Mot JSON: 'Motivé' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'd'information' - Similarité: 32%
# Mot JSON: 'Motivé' - Mot PDF: 'Ynov' - Similarité: 40%
# Mot JSON: 'Motivé' - Mot PDF: '(oct' - Similarité: 40%
# Mot JSON: 'Motivé' - Mot PDF: 'sept' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'besoins' - Similarité: 31%
# Mot JSON: 'Motivé' - Mot PDF: 'définition' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'stratégie' - Similarité: 27%
# Mot JSON: 'Motivé' - Mot PDF: 'modélisation' - Similarité: 33%
# Mot JSON: 'Motivé' - Mot PDF: 'informatique' - Similarité: 33%
# Mot JSON: 'Motivé' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'd'information.' - Similarité: 30%
# Mot JSON: 'Motivé' - Mot PDF: 'Mes' - Similarité: 22%
# Mot JSON: 'Motivé' - Mot PDF: 'qualités' - Similarité: 29%
# Mot JSON: 'Motivé' - Mot PDF: 'politique' - Similarité: 40%
# Mot JSON: 'Motivé' - Mot PDF: 'sécurité' - Similarité: 29%
# Mot JSON: 'Motivé' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'projet' - Similarité: 33%
# Mot JSON: 'Motivé' - Mot PDF: 'sont' - Similarité: 40%
# Mot JSON: 'Motivé' - Mot PDF: 'curiosité,' - Similarité: 38%
# Mot JSON: 'Motivé' - Mot PDF: 'capacité' - Similarité: 29%
# Mot JSON: 'Motivé' - Mot PDF: 'd'adaptation' - Similarité: 22%
# Mot JSON: 'Motivé' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'mon' - Similarité: 22%
# Mot JSON: 'Motivé' - Mot PDF: 'aptitude' - Similarité: 29%
# Mot JSON: 'Motivé' - Mot PDF: 'travailler' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'Maîtrise' - Similarité: 43%
# Mot JSON: 'Motivé' - Mot PDF: 'qualité' - Similarité: 31%
# Mot JSON: 'Motivé' - Mot PDF: 'projet' - Similarité: 33%
# Mot JSON: 'Motivé' - Mot PDF: 'Expiration' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'Mai' - Similarité: 44%
# Mot JSON: 'Motivé' - Mot PDF: 'projet' - Similarité: 33%
# Mot JSON: 'Motivé' - Mot PDF: 'mobilisant' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'Bootstrap' - Similarité: 27%
# Mot JSON: 'Motivé' - Mot PDF: 'Next' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'Native' - Similarité: 50%
# Mot JSON: 'Motivé' - Mot PDF: 'Android' - Similarité: 31%
# Mot JSON: 'Motivé' - Mot PDF: '(Kotlin)' - Similarité: 43%
# Mot JSON: 'Motivé' - Mot PDF: 'Node' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'MongoDB' - Similarité: 31%
# Mot JSON: 'Motivé' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'découvrir' - Similarité: 27%
# Mot JSON: 'Motivé' - Mot PDF: 'nouveaux' - Similarité: 29%
# Mot JSON: 'Motivé' - Mot PDF: 'endroits' - Similarité: 29%
# Mot JSON: 'Motivé' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'nouvelles' - Similarité: 27%
# Mot JSON: 'Motivé' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'créativité' - Similarité: 50%
# Mot JSON: 'Motivé' - Mot PDF: 'gastronomie' - Similarité: 24%
# Mot JSON: 'Motivé' - Mot PDF: 'pratique' - Similarité: 29%
# Mot JSON: 'Motivé' - Mot PDF: 'football' - Similarité: 29%
# Mot JSON: 'Motivé' - Mot PDF: 'Formation' - Similarité: 40%
# Mot JSON: 'Motivé' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'mobile' - Similarité: 33%
# Mot JSON: 'Motivé' - Mot PDF: '(nov' - Similarité: 40%
# Mot JSON: 'Motivé' - Mot PDF: 'sept' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'parties' - Similarité: 31%
# Mot JSON: 'Motivé' - Mot PDF: 'front-end' - Similarité: 27%
# Mot JSON: 'Motivé' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'application' - Similarité: 24%
# Mot JSON: 'Motivé' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'mobile' - Similarité: 33%
# Mot JSON: 'Motivé' - Mot PDF: 'Formation' - Similarité: 40%
# Mot JSON: 'Motivé' - Mot PDF: 'Foundation' - Similarité: 38%
# Mot JSON: 'Motivé' - Mot PDF: 'Création' - Similarité: 29%
# Mot JSON: 'Motivé' - Mot PDF: 'l’application' - Similarité: 21%
# Mot JSON: 'Motivé' - Mot PDF: 'scientifique' - Similarité: 22%
# Mot JSON: 'Motivé' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'mobile' - Similarité: 33%
# Mot JSON: 'Motivé' - Mot PDF: 'Totem' - Similarité: 36%
# Mot JSON: 'Motivé' - Mot PDF: '(oct' - Similarité: 40%
# Mot JSON: 'Motivé' - Mot PDF: 'sept' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'Concevoir' - Similarité: 27%
# Mot JSON: 'Motivé' - Mot PDF: 'l'application' - Similarité: 21%
# Mot JSON: 'Motivé' - Mot PDF: 'mobile' - Similarité: 33%
# Mot JSON: 'Motivé' - Mot PDF: 'applications' - Similarité: 22%
# Mot JSON: 'Motivé' - Mot PDF: 'applications' - Similarité: 22%
# Mot JSON: 'Motivé' - Mot PDF: 'mobiles' - Similarité: 31%
# Mot JSON: 'Motivé' - Mot PDF: 'native)' - Similarité: 46%
# Mot JSON: 'Motivé' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'mobile' - Similarité: 33%
# Mot JSON: 'Motivé' - Mot PDF: 'Tous' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'Marché,' - Similarité: 31%
# Mot JSON: 'Motivé' - Mot PDF: '(mai' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'aout' - Similarité: 40%
# Mot JSON: 'Motivé' - Mot PDF: 'Concevoir' - Similarité: 27%
# Mot JSON: 'Motivé' - Mot PDF: 'site' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'site' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'tailwind,' - Similarité: 27%
# Mot JSON: 'Motivé' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'données' - Similarité: 31%
# Mot JSON: 'Motivé' - Mot PDF: 'Gestion' - Similarité: 31%
# Mot JSON: 'Motivé' - Mot PDF: 'formation' - Similarité: 40%
# Mot JSON: 'Motivé' - Mot PDF: '(mai' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'contenu' - Similarité: 31%
# Mot JSON: 'Motivé' - Mot PDF: 'avec' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'HTML' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'réactive' - Similarité: 43%
# Mot JSON: 'Motivé' - Mot PDF: 'avec' - Similarité: 20%
# Mot JSON: 'Motivé' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'informatique' - Similarité: 33%
# Mot JSON: 'Motivé' - Mot PDF: 'MicroRezo,' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: '(oct' - Similarité: 40%
# Mot JSON: 'Motivé' - Mot PDF: 'installation' - Similarité: 22%
# Mot JSON: 'Motivé' - Mot PDF: 'logiciels' - Similarité: 27%
# Mot JSON: 'Motivé' - Mot PDF: 'informatiques' - Similarité: 32%
# Mot JSON: 'Motivé' - Mot PDF: 'et' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'reparation' - Similarité: 25%
# Mot JSON: 'Motivé' - Mot PDF: 'diverses' - Similarité: 29%
# Mot JSON: 'Motivé' - Mot PDF: 'électroniques' - Similarité: 21%
# Mot JSON: 'Motivé' - Mot PDF: 'font' - Similarité: 40%
# Mot JSON: 'Motivé' - Mot PDF: 'partie' - Similarité: 33%
# Mot JSON: 'Motivé' - Mot PDF: 'loisirs' - Similarité: 31%
# Mot JSON: 'Motivé' - Mot PDF: '(télephones,' - Similarité: 22%
